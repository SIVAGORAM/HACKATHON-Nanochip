# %% [markdown]
# <a href="https://colab.research.google.com/github/SIVAGORAM/HACKATHON-Nanochip/blob/main/NANOCHIP_HACKTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import plotly.graph_objs as go
import time

# Define constants
REAL_TIME_INTERVAL = 5  # Time interval for real-time processing (seconds)

# Function to generate random sensor readings (simulating real-time data)
def generate_sensor_readings():
    # Simulating sensor readings for demonstration
    features = {
        'temperature': np.random.randint(20, 30),  # Example temperature reading (20-30 degrees Celsius)
        'humidity': np.random.randint(40, 60),     # Example humidity reading (40-60%)
        'light_intensity': np.random.randint(100, 1000),  # Example light intensity reading
        'pressure': np.random.randint(900, 1100),  # Example pressure reading (900-1100 hPa)
        'wind_speed': np.random.randint(0, 30),    # Example wind speed reading (0-30 km/h)
        'CO2_level': np.random.randint(300, 1000), # Example CO2 level reading in ppm
        'oxygen_level': np.random.randint(18, 23)  # Example oxygen level reading in percentage
        # Add more sensor readings here as needed
    }
    return pd.DataFrame(features, index=[0])

# Function to retrieve historical sensor data from the cloud (placeholder)
def retrieve_historical_sensor_data():
    # Placeholder for connecting to the cloud and retrieving historical sensor data
    # Replace this with actual code to fetch historical sensor data from the cloud
    # For demonstration, let's create sample historical data
    sample_data = {
        'temperature': [25, 26, 27, 28, 29],
        'humidity': [50, 52, 55, 54, 53],
        'light_intensity': [800, 780, 820, 790, 810],
        'pressure': [1000, 990, 1010, 995, 1005],
        'wind_speed': [15, 12, 18, 20, 17],
        'CO2_level': [400, 420, 410, 430, 415],
        'oxygen_level': [20, 21, 19, 22, 20]
    }
    return pd.DataFrame(sample_data)

# Function for preprocessing sensor data
def preprocess_sensor_data(df):
    # Assuming preprocessing steps such as scaling may be required
    # For demonstration, let's keep it simple and return the DataFrame as is
    return df

# Function for real-time optimization and prediction
def optimize_and_predict(sensor_data, model):
    # Apply the trained model to predict energy consumption based on sensor data
    predicted_energy = model.predict(sensor_data)
    # Simulate optimization (example: doubling the sensor readings)
    optimized_sensor_data = sensor_data * 2
    return optimized_sensor_data, predicted_energy

# Function to visualize sensor data and predicted energy consumption
def visualize_results(sensor_data, optimized_sensor_data, predicted_energy):
    # Create interactive plot using Plotly
    fig = go.Figure()

    # Add original sensor readings
    for column in sensor_data.columns:
        fig.add_trace(go.Bar(x=[column], y=[sensor_data[column].iloc[0]], name="Original", marker_color='rgba(255, 0, 0, 0.5)'))

    # Add optimized sensor readings
    for column in optimized_sensor_data.columns:
        fig.add_trace(go.Bar(x=[column], y=[optimized_sensor_data[column].iloc[0]], name="Optimized", marker_color='rgba(0, 255, 0, 0.5)'))

    # Add predicted energy consumption
    fig.add_trace(go.Bar(x=['Predicted Energy'], y=predicted_energy, name="Predicted Energy", marker_color='rgba(0, 0, 255, 0.5)'))

    # Update layout
    fig.update_layout(title='Sensor Readings and Predicted Energy Consumption',
                      barmode='group',
                      xaxis=dict(title='Sensor'),
                      yaxis=dict(title='Value'))

    # Show plot
    fig.show()

# Function to save sensor readings, energy consumption, and predictions to a file
def save_data(sensor_data, predicted_energy):
    # Append data to a CSV file
    df = pd.concat([sensor_data, pd.DataFrame({'Predicted Energy': predicted_energy})], axis=1)
    df.to_csv('sensor_data_and_predictions.csv', mode='a', header=False, index=False)

# Main function
def main():
    # Retrieve historical sensor data from the cloud
    historical_sensor_data = retrieve_historical_sensor_data()

    # Preprocess the historical sensor data
    historical_sensor_data = preprocess_sensor_data(historical_sensor_data)

    # Train the model using historical sensor data (for demonstration)
    X_train = historical_sensor_data
    y_train = np.array([200, 220, 240, 230, 250])  # Example historical energy consumption
    model = Pipeline([('scaler', StandardScaler()), ('regressor', RandomForestRegressor())])
    model.fit(X_train, y_train)

    # Loop for real-time optimization and prediction
    while True:
        # Generate random sensor readings (simulating real-time data)
        sensor_data = generate_sensor_readings()

        # Preprocess the sensor data
        sensor_data = preprocess_sensor_data(sensor_data)

        # Perform real-time optimization and prediction
        optimized_sensor_data, predicted_energy = optimize_and_predict(sensor_data, model)

        # Visualize sensor data and predicted energy consumption
        visualize_results(sensor_data, optimized_sensor_data, predicted_energy)

        # Save sensor readings, energy consumption, and predictions to a file
        save_data(sensor_data, predicted_energy)

        # Sleep for some time (simulating real-time interval)
        time.sleep(REAL_TIME_INTERVAL)

if __name__ == "__main__":
    main()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="145220ac-4159-4a73-b099-59964ece583a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("145220ac-4159-4a73-b099-59964ece583a")) {                    Plotly.newPlot(                        "145220ac-4159-4a73-b099-59964ece583a",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[28],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[53],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[591],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[1016],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[13],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[886],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[19],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[56],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[106],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[1182],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[2032],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[26],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1772],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[38],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[231.0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="599dc4f1-bc00-4277-b9e2-fa580d6795a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("599dc4f1-bc00-4277-b9e2-fa580d6795a5")) {                    Plotly.newPlot(                        "599dc4f1-bc00-4277-b9e2-fa580d6795a5",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[26],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[42],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[271],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[964],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[28],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[505],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[22],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[52],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[84],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[542],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[1928],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[56],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1010],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[44],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[222.1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ef945468-0c73-47d5-8f1e-58173952f33e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef945468-0c73-47d5-8f1e-58173952f33e")) {                    Plotly.newPlot(                        "ef945468-0c73-47d5-8f1e-58173952f33e",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[20],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[54],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[880],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[991],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[27],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[811],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[19],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[40],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[108],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[1760],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[1982],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[54],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1622],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[38],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[226.4],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="487d1c3f-e7ae-4ef5-a811-151760ca92eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("487d1c3f-e7ae-4ef5-a811-151760ca92eb")) {                    Plotly.newPlot(                        "487d1c3f-e7ae-4ef5-a811-151760ca92eb",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[20],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[53],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[505],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[1064],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[10],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[842],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[19],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[40],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[106],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[1010],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[2128],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[20],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1684],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[38],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[224.1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5e695c0d-be00-418d-9df6-5ec094db8a56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e695c0d-be00-418d-9df6-5ec094db8a56")) {                    Plotly.newPlot(                        "5e695c0d-be00-418d-9df6-5ec094db8a56",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[22],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[59],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[901],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[1059],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[21],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[314],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[21],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[44],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[118],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[1802],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[2118],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[42],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[628],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[42],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[226.9],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fb35e5cd-3942-4e62-84b2-e68baeb92076" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb35e5cd-3942-4e62-84b2-e68baeb92076")) {                    Plotly.newPlot(                        "fb35e5cd-3942-4e62-84b2-e68baeb92076",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[25],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[52],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[425],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[953],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[21],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[920],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[19],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[50],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[104],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[850],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[1906],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[42],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1840],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[38],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[223.7],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="02a32dbe-ce53-4a42-8fd8-183e78c859a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02a32dbe-ce53-4a42-8fd8-183e78c859a2")) {                    Plotly.newPlot(                        "02a32dbe-ce53-4a42-8fd8-183e78c859a2",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[20],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[49],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[714],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[1070],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[4],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[595],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[19],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[40],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[98],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[1428],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[2140],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[8],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1190],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[38],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[217.6],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="49cbe459-6829-4aef-b11c-b700796c5773" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49cbe459-6829-4aef-b11c-b700796c5773")) {                    Plotly.newPlot(                        "49cbe459-6829-4aef-b11c-b700796c5773",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[21],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[55],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[524],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[986],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[20],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[586],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[22],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[42],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[110],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[1048],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[1972],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[40],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1172],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[44],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[225.2],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="36181743-bdee-4fab-a5bd-2df684f998d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36181743-bdee-4fab-a5bd-2df684f998d6")) {                    Plotly.newPlot(                        "36181743-bdee-4fab-a5bd-2df684f998d6",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[24],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[40],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[518],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[939],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[15],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[709],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[20],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[48],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[80],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[1036],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[1878],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[30],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1418],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[40],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[214.5],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e4957b5f-a887-4c7f-9e96-0e670ca2f1d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4957b5f-a887-4c7f-9e96-0e670ca2f1d2")) {                    Plotly.newPlot(                        "e4957b5f-a887-4c7f-9e96-0e670ca2f1d2",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[28],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[51],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[971],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[1051],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[2],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[818],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[22],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[56],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[102],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[1942],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[2102],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[4],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1636],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[44],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[226.5],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="19cc2d72-1b5b-404f-89db-46d73f00c535" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19cc2d72-1b5b-404f-89db-46d73f00c535")) {                    Plotly.newPlot(                        "19cc2d72-1b5b-404f-89db-46d73f00c535",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[27],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[42],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[298],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[927],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[0],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[654],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[18],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[54],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[84],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[596],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[1854],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[0],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1308],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[36],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[220.6],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4145e5b1-fb0e-43bf-a6d7-e0d01430cfca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4145e5b1-fb0e-43bf-a6d7-e0d01430cfca")) {                    Plotly.newPlot(                        "4145e5b1-fb0e-43bf-a6d7-e0d01430cfca",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[23],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[58],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[485],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[974],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[24],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[674],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[21],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[46],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[116],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[970],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[1948],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[48],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[1348],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[42],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[225.3],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="068091b8-2203-44fc-935f-a99e434199c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("068091b8-2203-44fc-935f-a99e434199c6")) {                    Plotly.newPlot(                        "068091b8-2203-44fc-935f-a99e434199c6",                        [{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["temperature"],"y":[23],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["humidity"],"y":[42],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["light_intensity"],"y":[603],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["pressure"],"y":[1096],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["wind_speed"],"y":[5],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["CO2_level"],"y":[399],"type":"bar"},{"marker":{"color":"rgba(255, 0, 0, 0.5)"},"name":"Original","x":["oxygen_level"],"y":[22],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["temperature"],"y":[46],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["humidity"],"y":[84],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["light_intensity"],"y":[1206],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["pressure"],"y":[2192],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["wind_speed"],"y":[10],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["CO2_level"],"y":[798],"type":"bar"},{"marker":{"color":"rgba(0, 255, 0, 0.5)"},"name":"Optimized","x":["oxygen_level"],"y":[44],"type":"bar"},{"marker":{"color":"rgba(0, 0, 255, 0.5)"},"name":"Predicted Energy","x":["Predicted Energy"],"y":[216.3],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222 ...
